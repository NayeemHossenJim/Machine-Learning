# %% [markdown]
# ## Initialize The CSV life

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("canada_per_capita_income.csv")
Scaler = MinMaxScaler()
df[["year"]] = Scaler.fit_transform(df[["year"]])
df[["Income"]] = Scaler.fit_transform(df[["Income"]])
df.head()
# Out:
#        year    Income
# 0  0.000000  0.000000
# 1  0.021739  0.009395
# 2  0.043478  0.021689
# 3  0.065217  0.035776
# 4  0.086957  0.055432

# %%
plt.xlabel("Year")
plt.ylabel("Income")
plt.scatter(df.year,df.Income,color = "red",marker="+")

# %% [markdown]
# ## Train Linear Model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.Income)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predictions

# %%
reg.predict([[2020]])
# Out:
# c:\Users\nayee\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1959.85205243])

# %%
plt.xlabel("Year")
plt.ylabel("Income")
plt.scatter(df.year,df.Income,color = "red",marker="+")
plt.plot(df.year,reg.predict(df[['year']]),color="blue")
